# %%
import pandas as pd
import numpy as np
from io import StringIO

# %% [markdown]
# Files needed: <br>
# * Teachers_export.csv
# * Staff-Export.csv

# %%
PS_Staff = pd.read_csv("Staff-Export.csv", encoding='latin-1')

# %%
PS_ActiveStaff = PS_Staff.loc[(PS_Staff["TEACHERS.Status"] == 1)]

# %%
PS_Staff_NotNull = PS_ActiveStaff.dropna(subset=['TEACHERS.Title'])

# %% [markdown]
# Fields <br>
# * Institution<br>
# * Primary Staff ID (State ID)<br>
# * Staff ID (District ID or School ID)<br>
# * LAST NAME<br>
# * FIRST NAME<br>
# * Access Privileges<br>
# * User Type<br>
# * Email<br>
# <br>
#
# Next up:
# Pull all fields for each of these job titles, create one dataframe/csv with the proper access privileges.

# %% [markdown]
# Creating an mClass staff file with the following permissions:
#
# * Principals - Full <br>
# * Assistant Principals - Full<br>
# * Teacher on Assignment - Full<br>
# * Instructional Coaches - Full<br>
# * Reading Specialists - Full<br>
# * Teachers - Standard<br>
# * SPED Teachers - Full<br>

# %%
df_AllTheFields = PS_Staff_NotNull[["TEACHERS.SchoolID","TEACHERS.TeacherNumber", "TEACHERS.Last_Name", "TEACHERS.First_Name", "TEACHERS.Email_Addr", "TEACHERS.Title"]]

# %%
df_AllTheFields
# Out:
#       TEACHERS.SchoolID TEACHERS.TeacherNumber TEACHERS.Last_Name  \
# 1                     0                   9000        Vierkoetter
# 8                   100                   1007            Khaaliq
# 12                  100                   1011           Cardinal
# 14                  100                   1013            Bennett
# 15                  100                   1014         Brownfield
# ...                 ...                    ...                ...
# 8965                250                   9115            Estrada
# 8966                150                   9116            Salinas
# 8967                450                   9117          Gutierrez
# 8968                100                   9118              Erick
# 8969                200                   9119           Mcgavran
#
#      TEACHERS.First_Name                       TEACHERS.Email_Addr  \
# 1              Elizabeth       liz.vierkoetter@vertexeducation.com
# ...

# %%
Staff_Principals = df_AllTheFields.loc[df_AllTheFields['TEACHERS.Title'].str.contains("Principal", case = False)]

# %%
Staff_Principals["User Type"] = "School Administrator"
Staff_Principals["Access Privileges"] = "Full"
# Out:
# C:\Users\LAUREN~1.GOL\AppData\Local\Temp/ipykernel_31672/1744349957.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Staff_Principals["User Type"] = "School Administrator"
# C:\Users\LAUREN~1.GOL\AppData\Local\Temp/ipykernel_31672/1744349957.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Staff_Principals["Access Privileges"] = "Full"

# %%
Staff_Principals
# Out:
#       TEACHERS.SchoolID TEACHERS.TeacherNumber TEACHERS.Last_Name  \
# 194                 150                   1197              Corak
# 500                 250                   1510           Bigoness
# 511                 250                   1521             Beitel
# 549                 350                   1561           Vanselow
# 601                 350                   1613             Martin
# 611                 350                   1623               Fite
# 2019                500                   2160            Bennett
# 2274                200                   4407              McCoy
# 2992                650                   5026              LaFon
# 3022                100                   5057              Pries
# 3089                450                   1701          Sanderson
# 3456                500                   5429               Leon
# 3561                150                   5501        Vierkoetter
# ...

# %% [markdown]
# <h5> Teacher on Assignment Added

# %%
Staff_TOA = df_AllTheFields.loc[df_AllTheFields['TEACHERS.Title'].str.contains("Teacher On Assignment", case = False)]

# %%
Staff_TOA
# Out:
#       TEACHERS.SchoolID TEACHERS.TeacherNumber TEACHERS.Last_Name  \
# 6549                900                   2073             Dailey
# 6776                850                   6120              Pence
#
#      TEACHERS.First_Name                  TEACHERS.Email_Addr  \
# 6549              Philip  philip.dailey@legacytraditional.org
# 6776               Susan    susan.pence@legacytraditional.org
#
#              TEACHERS.Title
# 6549  Teacher on Assignment
# 6776  Teacher On Assignment

# %%
Staff_TOA["User Type"] = "School Administrator"
Staff_TOA["Access Privileges"] = "System Access"
# Out:
# C:\Users\LAUREN~1.GOL\AppData\Local\Temp/ipykernel_31672/1249073359.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Staff_TOA["User Type"] = "School Administrator"
# C:\Users\LAUREN~1.GOL\AppData\Local\Temp/ipykernel_31672/1249073359.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Staff_TOA["Access Privileges"] = "System Access"

# %%
df_Final = Staff_Principals.append(Staff_TOA)

# %%
df_Final
# Out:
#       TEACHERS.SchoolID TEACHERS.TeacherNumber TEACHERS.Last_Name  \
# 194                 150                   1197              Corak
# 500                 250                   1510           Bigoness
# 511                 250                   1521             Beitel
# 549                 350                   1561           Vanselow
# 601                 350                   1613             Martin
# 611                 350                   1623               Fite
# 2019                500                   2160            Bennett
# 2274                200                   4407              McCoy
# 2992                650                   5026              LaFon
# 3022                100                   5057              Pries
# 3089                450                   1701          Sanderson
# 3456                500                   5429               Leon
# 3561                150                   5501        Vierkoetter
# ...

# %% [markdown]
# <h5> Instructional Coaches

# %%
InstructionalCoaches = df_AllTheFields.loc[df_AllTheFields['TEACHERS.Title'].str.contains("Instructional Coach", case = False)]

# %%
InstructionalCoaches.count()
# Out:
# TEACHERS.SchoolID         23
# TEACHERS.TeacherNumber    23
# TEACHERS.Last_Name        23
# TEACHERS.First_Name       23
# TEACHERS.Email_Addr       23
# TEACHERS.Title            23
# dtype: int64

# %%
InstructionalCoaches["User Type"] = "Specialist"
InstructionalCoaches["Access Privileges"] = "System Access"
# Out:
# C:\Users\LAUREN~1.GOL\AppData\Local\Temp/ipykernel_31672/640875382.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   InstructionalCoaches["User Type"] = "Specialist"
# C:\Users\LAUREN~1.GOL\AppData\Local\Temp/ipykernel_31672/640875382.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   InstructionalCoaches["Access Privileges"] = "System Access"

# %%
InstructionalCoaches
# Out:
#       TEACHERS.SchoolID TEACHERS.TeacherNumber TEACHERS.Last_Name  \
# 99                  100                   1101          Shoemaker
# 330                 200                   1336           Thomason
# 599                 350                   1611               Owen
# 2375                250                   4493            Johnson
# 2515                600                   1553          Vaninetti
# 2949                150                   4980              Pfadt
# 3039                500                   5074             Strand
# 3582                750                   5061               Ruiz
# 3744                750                   5678           Forayter
# 3806                300                   1042              Jones
# 3827                400                   5743             Elmore
# 5953                800                   2158            Wilkens
# 6106                500                   5823            Salerno
# ...

# %%
df_Final = df_Final.append(InstructionalCoaches)

# %% [markdown]
# <h5> ReadingSpecialists

# %%
ReadingSpecialists = df_AllTheFields.loc[df_AllTheFields['TEACHERS.Title'].str.contains("Reading Specialist", case = False)]

# %%
ReadingSpecialists["User Type"] = "Specialist"
ReadingSpecialists["Access Privileges"] = "System Access"
# Out:
# C:\Users\LAUREN~1.GOL\AppData\Local\Temp/ipykernel_31672/3418180298.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ReadingSpecialists["User Type"] = "Specialist"
# C:\Users\LAUREN~1.GOL\AppData\Local\Temp/ipykernel_31672/3418180298.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ReadingSpecialists["Access Privileges"] = "System Access"

# %%
df_Final = df_Final.append(ReadingSpecialists)

# %%
SPED_Teachers = df_AllTheFields.loc[df_AllTheFields['TEACHERS.Title'].str.contains("SPED Teacher", case = False)]

# %%
SPED_Teachers["User Type"] = "Specialist"
SPED_Teachers["Access Privileges"] = "System Access"
# Out:
# C:\Users\LAUREN~1.GOL\AppData\Local\Temp/ipykernel_31672/729746587.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SPED_Teachers["User Type"] = "Specialist"
# C:\Users\LAUREN~1.GOL\AppData\Local\Temp/ipykernel_31672/729746587.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SPED_Teachers["Access Privileges"] = "System Access"

# %%
df_Final = df_Final.append(SPED_Teachers)

# %% [markdown]
# <H5> 245 Rows of Admin and Staff - checked against original code

# %%
# Will have to add access and role for each of these (Admin, Specialist, etc.)

# %%
df_Final
# Out:
#       TEACHERS.SchoolID TEACHERS.TeacherNumber TEACHERS.Last_Name  \
# 194                 150                   1197              Corak
# 500                 250                   1510           Bigoness
# 511                 250                   1521             Beitel
# 549                 350                   1561           Vanselow
# 601                 350                   1613             Martin
# ...                 ...                    ...                ...
# 8886                100                   9043             Murray
# 8889                550                   9044           Fletcher
# 8905                100                   9060             George
# 8907                650                   9062             Parker
# 8916                100                   7907        Christenson
#
#      TEACHERS.First_Name                       TEACHERS.Email_Addr  \
# 194                Erica         erica.corak@legacytraditional.org
# ...

# %%
df_Final.rename(columns = {"TEACHERS.SchoolID": "SchoolID",'TEACHERS.Last_Name': 'LAST NAME', 'TEACHERS.First_Name': 'FIRST NAME', 'TEACHERS.Email_Addr': 'Email'}, inplace=True)

# %%
df_Final['Primary Staff ID (State ID)'] = df_Final['SchoolID'].astype(str) + '-' + df_Final['TEACHERS.TeacherNumber'].astype(str)

# %%
# Change School ID to Institution
transform_schoolID = {
    100:'Maricopa',
    150: 'Casa Grande',
    200: 'Queen Creek',
    250: 'Avondale',
    300: 'Chandler',
    350: 'Northwest Tucson',
    400: 'Laveen',
    450: 'Gilbert Elementary School',
    500: 'Surprise',
    550: 'North Chandler',
    600: 'Glendale',
    650: 'Peoria',
    700: 'East Mesa',
    750: 'Phoenix',
    800: 'Goodyear',
    850: 'North Phoenix',
    900: 'West Surprise',
    950: 'East Tucson',
    1000: 'Deer Valley',
    1050: 'Mesa',
    1100: 'Legacy Online Academy',
}

df_Final['Institution'] = df_Final['SchoolID'].map(transform_schoolID)

# %%
df_mClassStaffFile = df_Final.filter(['Institution','Primary Staff ID (State ID)', 'Staff ID (District ID or School ID)', 'LAST NAME', 'FIRST NAME', 'Access Privileges', 'User Type', 'Email'])

# %%
df_mClassStaffFile.to_csv('Legacy_Traditional_Schools_Arizona_staff.csv', index=False, encoding='utf-8')

# %%
df_Final.rename(columns = {"TEACHERS.SchoolID": "SchoolID",'TEACHERS.Last_Name': 'LAST NAME', 'TEACHERS.First_Name': 'FIRST NAME', 'TEACHERS.Email_Addr': 'Email'}, inplace=True)

# %%
df_Final['Primary Staff ID (State ID)'] = df_Final['SchoolID'].astype(str) + '-' + df_Final['TEACHERS.TeacherNumber'].astype(str)

# %%
df_Final["Staff ID (District ID or School ID)"] = ""

# %%
df_StaffAndAdminFile = df_Final[["SchoolID","Primary Staff ID (State ID)", "Staff ID (District ID or School ID)","LAST NAME","FIRST NAME","Access Privileges","User Type","Email"]]

# %%
df_mClassStaffFile
# Out:
#            Institution Primary Staff ID (State ID)    LAST NAME FIRST NAME  \
# 194        Casa Grande                    150-1197        Corak      Erica
# 500           Avondale                    250-1510     Bigoness       Lisa
# 511           Avondale                    250-1521       Beitel     Dennis
# 549   Northwest Tucson                    350-1561     Vanselow      Renee
# 601   Northwest Tucson                    350-1613       Martin    Ardemis
# ...                ...                         ...          ...        ...
# 8886          Maricopa                    100-9043       Murray      Emily
# 8889    North Chandler                    550-9044     Fletcher     Dennis
# 8905          Maricopa                    100-9060       George     Virgil
# 8907            Peoria                    650-9062       Parker   Adrienne
# 8916          Maricopa                    100-7907  Christenson     Connie
#
#      Access Privileges             User Type  \
# ...

# %% [markdown]
# <H5> Getting the same info from active teacher file

# %%
ActiveTeachers = pd.read_csv("Teachers_export.csv", encoding='latin-1')

# %%
ActiveTeachers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1274 entries, 0 to 1273
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   School ID               1274 non-null   int64
#  1   Title                   1274 non-null   object
#  2   Last Name               1274 non-null   object
#  3   First Name              1274 non-null   object
#  4   Middle Name             100 non-null    object
#  5   Email                   1274 non-null   object
#  6   PTAccess                1274 non-null   int64
#  7   Status                  1274 non-null   int64
#  8   TEACHERS.TeacherNumber  1274 non-null   object
#  9   TEACHERS.Users_DCID     1274 non-null   int64
# dtypes: int64(4), object(6)
# memory usage: 99.7+ KB

# %%
ActiveTeachers
# Out:
#       School ID                      Title             Last Name First Name  \
# 0           100             Kinder Teacher               Khaaliq     Malika
# 1           100          4th Grade Teacher              Cardinal     Cheryl
# 2           100          5th Grade Teacher               Bennett     Shawna
# 3           100         JH Eng/Lit Teacher            Brownfield    Cambria
# 4           100         Reading Specialist                Chavez    Melissa
# ...         ...                        ...                   ...        ...
# 1269       1050          Computers Teacher        Codling-Dichet     Leslie
# 1270        100  SPED Teacher (Contractor)                George     Virgil
# 1271        650  SPED Teacher (Contractor)                Parker   Adrienne
# 1272        400       Permanent Substitute  Samarakoon Jayaweera     Chitra
# 1273        100  SPED Teacher (Contractor)           Christenson     Connie
#
# ...

# %%
df_TeacherFields = ActiveTeachers[["School ID","TEACHERS.TeacherNumber", "Last Name", "First Name", "Email"]]

# %%
df_TeacherFields
# Out:
#       School ID TEACHERS.TeacherNumber             Last Name First Name  \
# 0           100                   1007               Khaaliq     Malika
# 1           100                   1011              Cardinal     Cheryl
# 2           100                   1013               Bennett     Shawna
# 3           100                   1014            Brownfield    Cambria
# 4           100                   1015                Chavez    Melissa
# ...         ...                    ...                   ...        ...
# 1269       1050                   9054        Codling-Dichet     Leslie
# 1270        100                   9060                George     Virgil
# 1271        650                   9062                Parker   Adrienne
# 1272        400                   9065  Samarakoon Jayaweera     Chitra
# 1273        100                   7907           Christenson     Connie
#
#                                                  Email
# ...

# %% [markdown]
# AZTeachers['Primary Staff ID (State ID)'] = AZTeachers['School ID'].astype(str) + '-' + AZTeachers['TEACHERS.TeacherNumber'].astype(str)

# %%
df_TeacherFields['Primary Staff ID (State ID)'] = df_TeacherFields['School ID'].astype(str) + '-' + df_TeacherFields['TEACHERS.TeacherNumber'].astype(str)
# Out:
# C:\Users\LAUREN~1.GOL\AppData\Local\Temp/ipykernel_31672/869341915.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_TeacherFields['Primary Staff ID (State ID)'] = df_TeacherFields['School ID'].astype(str) + '-' + df_TeacherFields['TEACHERS.TeacherNumber'].astype(str)

# %%
df_TeacherFields
# Out:
#       School ID TEACHERS.TeacherNumber             Last Name First Name  \
# 0           100                   1007               Khaaliq     Malika
# 1           100                   1011              Cardinal     Cheryl
# 2           100                   1013               Bennett     Shawna
# 3           100                   1014            Brownfield    Cambria
# 4           100                   1015                Chavez    Melissa
# ...         ...                    ...                   ...        ...
# 1269       1050                   9054        Codling-Dichet     Leslie
# 1270        100                   9060                George     Virgil
# 1271        650                   9062                Parker   Adrienne
# 1272        400                   9065  Samarakoon Jayaweera     Chitra
# 1273        100                   7907           Christenson     Connie
#
#                                                  Email  \
# ...

# %%
df_TeacherFields['Access Privileges'] = 'Standard'
df_TeacherFields['User Type'] = 'Teacher'
df_TeacherFields['Staff ID (District ID or School ID)'] = ''
# Out:
# C:\Users\LAUREN~1.GOL\AppData\Local\Temp/ipykernel_31672/791085409.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_TeacherFields['Access Privileges'] = 'Standard'
# C:\Users\LAUREN~1.GOL\AppData\Local\Temp/ipykernel_31672/791085409.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_TeacherFields['User Type'] = 'Teacher'
# C:\Users\LAUREN~1.GOL\AppData\Local\Temp/ipykernel_31672/791085409.py:3: SettingWithCopyWarning:
# ...

# %%
df_TeacherFields
# Out:
#       School ID TEACHERS.TeacherNumber             Last Name First Name  \
# 0           100                   1007               Khaaliq     Malika
# 1           100                   1011              Cardinal     Cheryl
# 2           100                   1013               Bennett     Shawna
# 3           100                   1014            Brownfield    Cambria
# 4           100                   1015                Chavez    Melissa
# ...         ...                    ...                   ...        ...
# 1269       1050                   9054        Codling-Dichet     Leslie
# 1270        100                   9060                George     Virgil
# 1271        650                   9062                Parker   Adrienne
# 1272        400                   9065  Samarakoon Jayaweera     Chitra
# 1273        100                   7907           Christenson     Connie
#
#                                                  Email  \
# ...

# %%
df_TeacherFields.rename(columns = {'Last Name': 'LAST NAME', 'First Name': 'FIRST NAME'}, inplace=True)
# Out:
# C:\Users\lauren.goldfish\Anaconda3\lib\site-packages\pandas\core\frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
df_TeacherFields
# Out:
#       School ID TEACHERS.TeacherNumber             LAST NAME FIRST NAME  \
# 0           100                   1007               Khaaliq     Malika
# 1           100                   1011              Cardinal     Cheryl
# 2           100                   1013               Bennett     Shawna
# 3           100                   1014            Brownfield    Cambria
# 4           100                   1015                Chavez    Melissa
# ...         ...                    ...                   ...        ...
# 1269       1050                   9054        Codling-Dichet     Leslie
# 1270        100                   9060                George     Virgil
# 1271        650                   9062                Parker   Adrienne
# 1272        400                   9065  Samarakoon Jayaweera     Chitra
# 1273        100                   7907           Christenson     Connie
#
#                                                  Email  \
# ...

# %%
df_TeachersFile = df_TeacherFields[["School ID","Primary Staff ID (State ID)", "Staff ID (District ID or School ID)","LAST NAME","FIRST NAME","Access Privileges","User Type","Email"]]

# %%
df_TeachersFile
# Out:
#       School ID Primary Staff ID (State ID)  \
# 0           100                    100-1007
# 1           100                    100-1011
# 2           100                    100-1013
# 3           100                    100-1014
# 4           100                    100-1015
# ...         ...                         ...
# 1269       1050                   1050-9054
# 1270        100                    100-9060
# 1271        650                    650-9062
# 1272        400                    400-9065
# 1273        100                    100-7907
#
#      Staff ID (District ID or School ID)             LAST NAME FIRST NAME  \
# 0                                                      Khaaliq     Malika
# 1                                                     Cardinal     Cheryl
# 2                                                      Bennett     Shawna
# 3                                                   Brownfield    Cambria
# ...

# %%
# rename that column
df_StaffAndAdminFile.rename(columns = {'SchoolID': 'School ID'}, inplace=True)
# Out:
# C:\Users\lauren.goldfish\Anaconda3\lib\site-packages\pandas\core\frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
df_StaffAndAdminFile
# Out:
#       School ID Primary Staff ID (State ID)  \
# 194         150                    150-1197
# 500         250                    250-1510
# 511         250                    250-1521
# 549         350                    350-1561
# 601         350                    350-1613
# ...         ...                         ...
# 8886        100                    100-9043
# 8889        550                    550-9044
# 8905        100                    100-9060
# 8907        650                    650-9062
# 8916        100                    100-7907
#
#      Staff ID (District ID or School ID)    LAST NAME FIRST NAME  \
# 194                                             Corak      Erica
# 500                                          Bigoness       Lisa
# 511                                            Beitel     Dennis
# 549                                          Vanselow      Renee
# 601                                            Martin    Ardemis
# ...

# %%
df_AlmostThere = df_StaffAndAdminFile.append(df_TeachersFile)

# %%
df_AlmostThere
# Out:
#       School ID Primary Staff ID (State ID)  \
# 194         150                    150-1197
# 500         250                    250-1510
# 511         250                    250-1521
# 549         350                    350-1561
# 601         350                    350-1613
# ...         ...                         ...
# 1269       1050                   1050-9054
# 1270        100                    100-9060
# 1271        650                    650-9062
# 1272        400                    400-9065
# 1273        100                    100-7907
#
#      Staff ID (District ID or School ID)             LAST NAME FIRST NAME  \
# 194                                                      Corak      Erica
# 500                                                   Bigoness       Lisa
# 511                                                     Beitel     Dennis
# 549                                                   Vanselow      Renee
# ...

# %%
# Change School ID to Institution
transform_schoolID = {
    100:'Maricopa',
    150: 'Casa Grande',
    200: 'Queen Creek',
    250: 'Avondale',
    300: 'Chandler',
    350: 'Northwest Tucson',
    400: 'Laveen',
    450: 'Gilbert Elementary School',
    500: 'Surprise',
    550: 'North Chandler',
    600: 'Glendale',
    650: 'Peoria',
    700: 'East Mesa',
    750: 'Phoenix',
    800: 'Goodyear',
    850: 'North Phoenix',
    900: 'West Surprise',
    950: 'East Tucson',
    1000: 'Deer Valley',
    1050: 'Mesa',
    1100: 'Legacy Online Academy',
}

df_AlmostThere['Institution'] = df_AlmostThere['School ID'].map(transform_schoolID)

# %%
df_AlmostThere
# Out:
#       School ID Primary Staff ID (State ID)  \
# 194         150                    150-1197
# 500         250                    250-1510
# 511         250                    250-1521
# 549         350                    350-1561
# 601         350                    350-1613
# ...         ...                         ...
# 1269       1050                   1050-9054
# 1270        100                    100-9060
# 1271        650                    650-9062
# 1272        400                    400-9065
# 1273        100                    100-7907
#
#      Staff ID (District ID or School ID)             LAST NAME FIRST NAME  \
# 194                                                      Corak      Erica
# 500                                                   Bigoness       Lisa
# 511                                                     Beitel     Dennis
# 549                                                   Vanselow      Renee
# ...

# %%
df_mClassStaffFile = df_AlmostThere.filter(['Institution','Primary Staff ID (State ID)', 'Staff ID (District ID or School ID)', 'LAST NAME', 'FIRST NAME', 'Access Privileges', 'User Type', 'Email'])

# %%
df_mClassStaffFile
# Out:
#            Institution Primary Staff ID (State ID)  \
# 194        Casa Grande                    150-1197
# 500           Avondale                    250-1510
# 511           Avondale                    250-1521
# 549   Northwest Tucson                    350-1561
# 601   Northwest Tucson                    350-1613
# ...                ...                         ...
# 1269              Mesa                   1050-9054
# 1270          Maricopa                    100-9060
# 1271            Peoria                    650-9062
# 1272            Laveen                    400-9065
# 1273          Maricopa                    100-7907
#
#      Staff ID (District ID or School ID)             LAST NAME FIRST NAME  \
# 194                                                      Corak      Erica
# 500                                                   Bigoness       Lisa
# 511                                                     Beitel     Dennis
# ...

# %%
df_mClassStaffFile.to_csv('Legacy_Traditional_Schools_Arizona_staff.csv', index=False, encoding='utf-8')
