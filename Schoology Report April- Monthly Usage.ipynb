# %%
import pandas as pd
import numpy as np
from io import StringIO
from datetime import datetime as dt
import math

# %% [markdown]
# <H4> Looking for materials: Science, Reading, Grammar/Writing, data for each subject by school, teacher or student, date (?)

# %%
# April First

# %%
df_April = pd.read_csv("AllAprilData.csv", encoding='latin-1')
# Out:
# C:\Users\lauren.goldfish\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (26) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
# , format = '%m%d%Y'

# %%
# 630,102 rows
df_April.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 630102 entries, 0 to 630101
# Data columns (total 35 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   role_name             630102 non-null  object
#  1   user_building_id      630102 non-null  int64
#  2   user_building_name    630102 non-null  object
#  3   username              630102 non-null  object
#  4   email                 630091 non-null  object
#  5   schoology_user_id     630102 non-null  int64
#  6   unique_user_id        627152 non-null  object
#  7   action_type           630102 non-null  object
#  8   item_type             630102 non-null  object
#  9   item_id               555482 non-null  float64
#  10  item_name             553452 non-null  object
#  11  course_name           548936 non-null  object
#  12  course_code           543493 non-null  object
#  13  section_name          548936 non-null  object
#  14  last_event_timestamp  630102 non-null  object
#  15  event_count           630102 non-null  int64
#  16  role_id               630102 non-null  int64
#  17  user_building_code    0 non-null       float64
#  18  last_name             630102 non-null  object
#  19  first_name            630102 non-null  object
#  20  device_type           630102 non-null  object
#  21  item_building_id      629983 non-null  float64
#  22  item_building_name    629983 non-null  object
#  23  item_building_code    0 non-null       float64
#  24  item_parent_type      630102 non-null  object
#  25  group_id              3789 non-null    float64
#  26  group_name            3789 non-null    object
#  27  course_id             548936 non-null  float64
#  28  section_id            548936 non-null  float64
#  29  section_school_code   543417 non-null  float64
#  30  section_code          58 non-null      float64
#  31  month                 630102 non-null  int64
#  32  date                  630102 non-null  object
#  33  timestamp             630102 non-null  object
#  34  time spent (seconds)  20390 non-null   float64
# dtypes: float64(10), int64(5), object(20)
# memory usage: 168.3+ MB

# %%
df_April['date'] = pd.to_datetime(df_April['date'])

# %%
df_April['date'].min()
# Out:
# Timestamp('2022-04-01 00:00:00')

# %%
df_April['date'].max()
# Out:
# Timestamp('2022-04-30 00:00:00')

# %%
# Drop all null course names, down to 1,519,599 rows
df_April_NotNull = df_April.dropna(subset=['course_name'])

# %%
# 548,936 rows
df_April_NotNull.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 548936 entries, 0 to 630101
# Data columns (total 35 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   role_name             548936 non-null  object
#  1   user_building_id      548936 non-null  int64
#  2   user_building_name    548936 non-null  object
#  3   username              548936 non-null  object
#  4   email                 548936 non-null  object
#  5   schoology_user_id     548936 non-null  int64
#  6   unique_user_id        547368 non-null  object
#  7   action_type           548936 non-null  object
#  8   item_type             548936 non-null  object
#  9   item_id               548879 non-null  float64
#  10  item_name             547922 non-null  object
#  11  course_name           548936 non-null  object
#  12  course_code           543493 non-null  object
#  13  section_name          548936 non-null  object
#  14  last_event_timestamp  548936 non-null  object
#  15  event_count           548936 non-null  int64
#  16  role_id               548936 non-null  int64
#  17  user_building_code    0 non-null       float64
#  18  last_name             548936 non-null  object
#  19  first_name            548936 non-null  object
#  20  device_type           548936 non-null  object
#  21  item_building_id      548936 non-null  float64
#  22  item_building_name    548936 non-null  object
#  23  item_building_code    0 non-null       float64
#  24  item_parent_type      548936 non-null  object
#  25  group_id              0 non-null       float64
#  26  group_name            0 non-null       object
#  27  course_id             548936 non-null  float64
#  28  section_id            548936 non-null  float64
#  29  section_school_code   543417 non-null  float64
#  30  section_code          58 non-null      float64
#  31  month                 548936 non-null  int64
#  32  date                  548936 non-null  datetime64[ns]
#  33  timestamp             548936 non-null  object
#  34  time spent (seconds)  20390 non-null   float64
# dtypes: datetime64[ns](1), float64(10), int64(5), object(19)
# memory usage: 150.8+ MB

# %%
# Grammar, no filter: 69,933 rows × 35 columns
df_coursename_grammar = df_April_NotNull.loc[df_April_NotNull['course_name'].str.contains("grammar", case = False)]

# %%
df_coursename_grammar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 69933 entries, 11 to 630096
# Data columns (total 35 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   role_name             69933 non-null  object
#  1   user_building_id      69933 non-null  int64
#  2   user_building_name    69933 non-null  object
#  3   username              69933 non-null  object
#  4   email                 69933 non-null  object
#  5   schoology_user_id     69933 non-null  int64
#  6   unique_user_id        69768 non-null  object
#  7   action_type           69933 non-null  object
#  8   item_type             69933 non-null  object
#  9   item_id               69933 non-null  float64
#  10  item_name             69918 non-null  object
#  11  course_name           69933 non-null  object
#  12  course_code           69933 non-null  object
#  13  section_name          69933 non-null  object
#  14  last_event_timestamp  69933 non-null  object
#  15  event_count           69933 non-null  int64
#  16  role_id               69933 non-null  int64
#  17  user_building_code    0 non-null      float64
#  18  last_name             69933 non-null  object
#  19  first_name            69933 non-null  object
#  20  device_type           69933 non-null  object
#  21  item_building_id      69933 non-null  float64
#  22  item_building_name    69933 non-null  object
#  23  item_building_code    0 non-null      float64
#  24  item_parent_type      69933 non-null  object
#  25  group_id              0 non-null      float64
#  26  group_name            0 non-null      object
#  27  course_id             69933 non-null  float64
#  28  section_id            69933 non-null  float64
#  29  section_school_code   69933 non-null  float64
#  30  section_code          0 non-null      float64
#  31  month                 69933 non-null  int64
#  32  date                  69933 non-null  datetime64[ns]
#  33  timestamp             69933 non-null  object
#  34  time spent (seconds)  2469 non-null   float64
# dtypes: datetime64[ns](1), float64(10), int64(5), object(19)
# memory usage: 19.2+ MB

# %%
# Science, no filter: 45,537 rows
df_coursename_science = df_April_NotNull.loc[df_April_NotNull['course_name'].str.contains("science", case = False)]

# %%
df_coursename_science.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45537 entries, 0 to 630024
# Data columns (total 35 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   role_name             45537 non-null  object
#  1   user_building_id      45537 non-null  int64
#  2   user_building_name    45537 non-null  object
#  3   username              45537 non-null  object
#  4   email                 45537 non-null  object
#  5   schoology_user_id     45537 non-null  int64
#  6   unique_user_id        45437 non-null  object
#  7   action_type           45537 non-null  object
#  8   item_type             45537 non-null  object
#  9   item_id               45537 non-null  float64
#  10  item_name             45455 non-null  object
#  11  course_name           45537 non-null  object
#  12  course_code           45537 non-null  object
#  13  section_name          45537 non-null  object
#  14  last_event_timestamp  45537 non-null  object
#  15  event_count           45537 non-null  int64
#  16  role_id               45537 non-null  int64
#  17  user_building_code    0 non-null      float64
#  18  last_name             45537 non-null  object
#  19  first_name            45537 non-null  object
#  20  device_type           45537 non-null  object
#  21  item_building_id      45537 non-null  float64
#  22  item_building_name    45537 non-null  object
#  23  item_building_code    0 non-null      float64
#  24  item_parent_type      45537 non-null  object
#  25  group_id              0 non-null      float64
#  26  group_name            0 non-null      object
#  27  course_id             45537 non-null  float64
#  28  section_id            45537 non-null  float64
#  29  section_school_code   45487 non-null  float64
#  30  section_code          50 non-null     float64
#  31  month                 45537 non-null  int64
#  32  date                  45537 non-null  datetime64[ns]
#  33  timestamp             45537 non-null  object
#  34  time spent (seconds)  2431 non-null   float64
# dtypes: datetime64[ns](1), float64(10), int64(5), object(19)
# memory usage: 12.5+ MB

# %%
# Reading, no filter: 69,860 rows
df_coursename_reading = df_April_NotNull.loc[df_April_NotNull['course_name'].str.contains("reading", case = False)]

# %%
df_coursename_reading.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 69860 entries, 124 to 630098
# Data columns (total 35 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   role_name             69860 non-null  object
#  1   user_building_id      69860 non-null  int64
#  2   user_building_name    69860 non-null  object
#  3   username              69860 non-null  object
#  4   email                 69860 non-null  object
#  5   schoology_user_id     69860 non-null  int64
#  6   unique_user_id        69778 non-null  object
#  7   action_type           69860 non-null  object
#  8   item_type             69860 non-null  object
#  9   item_id               69860 non-null  float64
#  10  item_name             69832 non-null  object
#  11  course_name           69860 non-null  object
#  12  course_code           69860 non-null  object
#  13  section_name          69860 non-null  object
#  14  last_event_timestamp  69860 non-null  object
#  15  event_count           69860 non-null  int64
#  16  role_id               69860 non-null  int64
#  17  user_building_code    0 non-null      float64
#  18  last_name             69860 non-null  object
#  19  first_name            69860 non-null  object
#  20  device_type           69860 non-null  object
#  21  item_building_id      69860 non-null  float64
#  22  item_building_name    69860 non-null  object
#  23  item_building_code    0 non-null      float64
#  24  item_parent_type      69860 non-null  object
#  25  group_id              0 non-null      float64
#  26  group_name            0 non-null      object
#  27  course_id             69860 non-null  float64
#  28  section_id            69860 non-null  float64
#  29  section_school_code   69860 non-null  float64
#  30  section_code          0 non-null      float64
#  31  month                 69860 non-null  int64
#  32  date                  69860 non-null  datetime64[ns]
#  33  timestamp             69860 non-null  object
#  34  time spent (seconds)  2943 non-null   float64
# dtypes: datetime64[ns](1), float64(10), int64(5), object(19)
# memory usage: 19.2+ MB

# %% [markdown]
# Necessary columns - to remove duplicates - one month's usage:
# - role_name <br>
# - user_building_name <br>
# - course_name <br>
# - date <br>

# %% [markdown]
# <H3> Sorting each subject by required fields

# %%
# 1,751 rows
df_grammar_filter = df_coursename_grammar.filter(['role_name','schoology_user_id', 'user_building_name', 'course_name'])
df_grammar = df_grammar_filter.drop_duplicates()

# %%
df_grammar
# Out:
#        role_name  schoology_user_id  \
# 11       Student           94776841
# 12       Student           94769751
# 17       Student           95606794
# 22       Student          100181687
# 27       Student           94782319
# ...          ...                ...
# 627052   Student           94780648
# 627707    Parent          112759235
# 627835   Student           94783552
# 628052   Student          107879963
# 630079   Student          107886299
#
#                                 user_building_name      course_name
# 11                           Legacy Online Academy  Grammar/Writing
# 12            Legacy Traditional School - Chandler  Grammar/Writing
# 17       Legacy Traditional School - West Surprise  Grammar/Writing
# 22                           Legacy Online Academy  Grammar/Writing
# 27                           Legacy Online Academy  Grammar/Writing
# ...                                            ...              ...
# 627052        Legacy Traditional School - Maricopa  Grammar/Writing
# 627707                       Legacy Online Academy  Grammar/Writing
# 627835       Legacy Traditional School - NW Tucson  Grammar/Writing
# 628052  Legacy Traditional School - North Chandler  Grammar/Writing
# 630079   Legacy Traditional School - West Surprise  Grammar/Writing
#
# [1751 rows x 4 columns]

# %%
# 3,018 rows
df_science_filter = df_coursename_science.filter(['role_name', 'schoology_user_id', 'user_building_name', 'course_name'])
df_science = df_science_filter.drop_duplicates()

# %%
df_science
# Out:
#        role_name  schoology_user_id  \
# 0        Student           94767962
# 1        Student           94774211
# 6        Student           94769761
# 50       Student           94779240
# 61       Student           94775598
# ...          ...                ...
# 625049   Student          107886032
# 625816   Student           94775211
# 628522   Student           94773435
# 628912   Student          113749539
# 629354   Student          107880064
#
#                                 user_building_name        course_name
# 0                            Legacy Online Academy            Science
# 1             Legacy Traditional School - Avondale            Science
# 6             Legacy Traditional School - Chandler            Science
# 50              Legacy Traditional School - Laveen  7th Grade Science
# 61         Legacy Traditional School - Casa Grande            Science
# ...                                            ...                ...
# 625049   Legacy Traditional School - North Phoenix  7th Grade Science
# 625816        Legacy Traditional School - Avondale  8th Grade Science
# 628522        Legacy Traditional School - Maricopa            Science
# 628912        Legacy Traditional School - Chandler            Science
# 629354  Legacy Traditional School - North Chandler            Science
#
# [3018 rows x 4 columns]

# %%
# 1,871 rows
df_reading_filter = df_coursename_reading.filter(['role_name', 'schoology_user_id', 'user_building_name', 'course_name'])
df_reading = df_reading_filter.drop_duplicates()

# %%
df_reading
# Out:
#        role_name  schoology_user_id  \
# 124      Student           94774236
# 148      Student          108672330
# 258      Student           94776225
# 276      Student           94779945
# 282      Student           94783980
# ...          ...                ...
# 629022    Parent           98673987
# 629075   Student           98607675
# 629431   Student           94771248
# 629797   Student          107886299
# 630038   Student           94773954
#
#                                user_building_name course_name
# 124          Legacy Traditional School - Avondale     Reading
# 148                         Legacy Online Academy     Reading
# 258                         Legacy Online Academy     Reading
# 276            Legacy Traditional School - Laveen     Reading
# 282          Legacy Traditional School - Surprise     Reading
# ...                                           ...         ...
# 629022       Legacy Traditional School - Maricopa     Reading
# 629075       Legacy Traditional School - Maricopa     Reading
# 629431      Legacy Traditional School - East Mesa     Reading
# 629797  Legacy Traditional School - West Surprise     Reading
# 630038  Legacy Traditional School - West Surprise     Reading
#
# [1871 rows x 4 columns]

# %%
# pd.concat([t1, t2, t3, t4, t5])
df_April_ScienceReadingGrammar = pd.concat([df_reading, df_science, df_grammar])

# %%
# 27,222 rows, as predicted
df_April_ScienceReadingGrammar
# Out:
#        role_name  schoology_user_id  \
# 124      Student           94774236
# 148      Student          108672330
# 258      Student           94776225
# 276      Student           94779945
# 282      Student           94783980
# ...          ...                ...
# 627052   Student           94780648
# 627707    Parent          112759235
# 627835   Student           94783552
# 628052   Student          107879963
# 630079   Student          107886299
#
#                                 user_building_name      course_name
# 124           Legacy Traditional School - Avondale          Reading
# 148                          Legacy Online Academy          Reading
# 258                          Legacy Online Academy          Reading
# 276             Legacy Traditional School - Laveen          Reading
# 282           Legacy Traditional School - Surprise          Reading
# ...                                            ...              ...
# 627052        Legacy Traditional School - Maricopa  Grammar/Writing
# 627707                       Legacy Online Academy  Grammar/Writing
# 627835       Legacy Traditional School - NW Tucson  Grammar/Writing
# 628052  Legacy Traditional School - North Chandler  Grammar/Writing
# 630079   Legacy Traditional School - West Surprise  Grammar/Writing
#
# [6640 rows x 4 columns]

# %%
df_April_ScienceReadingGrammar.to_csv('ScienceReadingGrammarMonthlyApril.csv', encoding='utf-8', index = False)
